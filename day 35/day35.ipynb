# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("data_science_job.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
#count how many rows are null in each column
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
cols= [cols for cols in df.columns if df[cols].isnull().mean()> 0 and df[cols].isnull().mean()< 0.05]

# %%
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 331                     0.865       no_enrollment             NaN         3.0
# 13674                   0.624    Full time course     High School         7.0
# 2164                    0.624    Full time course        Graduate        20.0
# 7332                    0.920       no_enrollment         Masters        20.0
# 9125                    0.920       no_enrollment        Graduate         4.0
#
#        training_hours
# 331             302.0
# 13674            94.0
# 2164             47.0
# 7332            145.0
# 9125              4.0

# %%
df['enrolled_university'].value_counts()
# Out:
# enrolled_university
# no_enrollment       13817
# Full time course     3757
# Part time course     1198
# Name: count, dtype: int64

# %%
new_df= df[cols].dropna()

# %%
len(new_df)/len(df)
# Out:
# 0.8968577095730244

# %%
new_df.hist(bins=50, figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'city_development_index'}>,
#         <Axes: title={'center': 'experience'}>],
#        [<Axes: title={'center': 'training_hours'}>, <Axes: >]],
#       dtype=object)

# %%
plt.show()
